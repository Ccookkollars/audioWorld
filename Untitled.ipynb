# %%
import sounddevice as sdd
import struct
import math
import numpy as np
import pandas as pd
import queue
from matplotlib import pyplot as plt
import csv
# %matplotlib notebook

# %%
aud = dict()
aud['samplerate'] = 44100
aud['channels'] = 1
with open(r'/home/caleb/Downloads/002.wav', 'rb') as f:
    #riff
    print(' RIFF, filesize, WAVE')
    print(struct.unpack('4si4s', f.read(12)))
    print('\n subchunk1: fmt, size')
    print(struct.unpack('4si', f.read(8)))
    #format pcm = 1, channels mono = 1
    print(' pcm = 1, channels mono = 1')
    print(struct.unpack('hh', f.read(4)))
    #samplerate
    print(' samplerate, byterate')
    print(struct.unpack('ii', f.read(8)))
    print(' bytes per sample, bits per sample')
    (Bps, bps) = struct.unpack('hh', f.read(4))
    print((Bps, bps))
    
    while True:
        print('\n subchunkid')
        subch_name = struct.unpack('4s', f.read(4))
        subch_name = subch_name[0]
        print(subch_name)
        if subch_name == b'data':
            break;
        #subchunksize
        sz = struct.unpack('i', f.read(4))
        sz = sz[0]
        f.read(sz)
    
    sz = struct.unpack('i', f.read(4))
    adat = np.array(struct.unpack('h'*int(sz[0]/2), f.read(sz[0]))).astype(np.float)/37260
# Out:
#  RIFF, filesize, WAVE
# (b'RIFF', 1906758, b'WAVE')
#
#  subchunk1: fmt, size
# (b'fmt ', 16)
#  pcm = 1, channels mono = 1
# (1, 1)
#  samplerate, byterate
# (44100, 88200)
#  bytes per sample, bits per sample
# (2, 16)
#
#  subchunkid
# b'LIST'
#
#  subchunkid
# b'data'

# %%
start = 7
sec = 5
bdat = adat[start*44100:(44100*(start+sec))]
sdd.play(bdat)
print(len(bdat))
print(pd.DataFrame(bdat))
# Out:
# 220500
#                0
# 0       0.007193
# 1       0.000564
# 2      -0.009018
# 3      -0.002093
# 4      -0.014922
# 5      -0.014144
# 6      -0.021176
# 7      -0.023913
# 8       0.000698
# 9       0.001181
# 10      0.007864
# 11      0.011379
# 12      0.015405
# 13      0.020800
# 14      0.003247
# 15     -0.000429
# 16     -0.013392
# 17      0.001906
# 18      0.005448
# 19     -0.009045
# 20     -0.006173
# 21     -0.019995
# 22     -0.009447
# 23     -0.011997
# 24     -0.008132
# 25      0.006575
# 26      0.008186
# 27      0.010413
# 28      0.003435
# 29     -0.000725
# ...          ...
# 220470 -0.208293
# 220471 -0.173081
# 220472 -0.125416
# 220473 -0.110843
# 220474 -0.119753
# 220475 -0.127831
# 220476 -0.197665
# 220477 -0.276838
# 220478 -0.355072
# 220479 -0.478422
# 220480 -0.526946
# 220481 -0.536661
# 220482 -0.516210
# 220483 -0.440284
# 220484 -0.356897
# 220485 -0.264251
# 220486 -0.240982
# 220487 -0.158857
# 220488 -0.108052
# 220489 -0.098417
# ...

# %%
notenames = []
notefreqs = []
with open(r'/home/caleb/projects/audioWorld/notes.csv', 'r') as f:
    reader = csv.reader(f)
    for line in reader:
        notenames.append(line[1])
        notefreqs.append(float(line[2]))
print(pd.DataFrame(list(zip(notenames, notefreqs))))
# Out:
#            0        1
# 0         C0    16.35
# 1    C#0/Db0    17.32
# 2         D0    18.35
# 3    D#0/Eb0    19.45
# 4         E0    20.60
# 5         F0    21.83
# 6    F#0/Gb0    23.12
# 7         G0    24.50
# 8    G#0/Ab0    25.96
# 9         A0    27.50
# 10   A#0/Bb0    29.14
# 11        B0    30.87
# 12        C1    32.70
# 13   C#1/Db1    34.65
# 14        D1    36.71
# 15   D#1/Eb1    38.89
# 16        E1    41.20
# 17        F1    43.65
# 18   F#1/Gb1    46.25
# 19        G1    49.00
# 20   G#1/Ab1    51.91
# 21        A1    55.00
# 22   A#1/Bb1    58.27
# 23        B1    61.74
# 24        C2    65.41
# 25   C#2/Db2    69.30
# 26        D2    73.42
# 27   D#2/Eb2    77.78
# 28        E2    82.41
# 29        F2    87.31
# ..       ...      ...
# 78   F#6/Gb6  1479.98
# 79        G6  1567.98
# 80   G#6/Ab6  1661.22
# 81        A6  1760.00
# 82   A#6/Bb6  1864.66
# 83        B6  1975.53
# 84        C7  2093.00
# 85   C#7/Db7  2217.46
# 86        D7  2349.32
# ...

# %%
i = 40
print(notenames[i], notefreqs[i])
t = np.arange(0,1,1/aud['samplerate'])
wav = np.ones(len(t))
wav = np.sin(t*2*math.pi*notefreqs[i])
wav *= np.sin(t*2*math.pi*notefreqs[i]*2)
wav *= np.sin(t*2*math.pi*notefreqs[i]*4)
# wav = wav*np.hamming(2*aud['samplerate'])
# plt.plot(t, wav)
def fade(dat):
    result = dat
    onepad = np.ones(len(dat))
    n = 44100/4
    hw = np.hanning(n)
    for i in range(int(n/2)):
        result[i] = dat[i] * hw[i]
        result[len(dat)-i-1] = dat[len(dat)-i-1] * hw[i]
    return result

wav = fade(wav)
plt.plot(wav[22050:44100])
sdd.play(wav)
# plt.plot(np.hanning(len(wav))*wav)
# sdd.play(np.hanning(len(wav))*wav)
# Out:
# E3 164.81
# <img src="data:image/png;base64,..." width="640">

# %%
from mpl_toolkits.mplot3d import Axes3D
nsamp = 2** 14 # 16384 is near double the highest note (7902.13)
nfft = int(nsamp / 2) + 1
X = list(range(nfft))
Y = [1]*nfft
postfft = np.fft.rfft(bdat[0:nsamp])
plt.plot(postfft)
plt.show()
for i in range(10000):
    if nsamp*(i+2) > len(bdat):
        break
    X.extend(list(range(nfft)))
    Y.extend([i+1]*nfft)
    fftdat = np.fft.rfft(bdat[nsamp*(i+1):nsamp*(i+2)])
    fftdat = np.abs(fftdat) * [math.log(x) for x in range(1, nfft+1)]
    postfft = np.append(postfft, fftdat)

print(type(X), len(X), type(Y),  len(Y), type(postfft), len(postfft))

fig = plt.figure()
ax = fig.gca(projection='3d')

ax.set_xlabel('fftnumber')
ax.set_ylabel('slice')
scatt = ax.scatter(X, Y, np.abs(postfft), c=np.abs(postfft), marker='.')
# X, Y = np.meshgrid(list(range(nfft)), list(range(int(len(X)/nfft))))
# Z = np.reshape(postfft, [int(len(postfft)/nfft), nfft])
# print(X.shape, Y.shape, Z.shape)
# scatt = ax.scatter(X, Y, Z, c=Z, marker='.')
plt.show()
# Out:
# /home/caleb/anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py:492: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# <class 'list'> 106509 <class 'list'> 106509 <class 'numpy.ndarray'> 106509

# %%
print(pd.DataFrame([(i, 2**i) for i in range(30)]))
# Out:
#      0          1
# 0    0          1
# 1    1          2
# 2    2          4
# 3    3          8
# 4    4         16
# 5    5         32
# 6    6         64
# 7    7        128
# 8    8        256
# 9    9        512
# 10  10       1024
# 11  11       2048
# 12  12       4096
# 13  13       8192
# 14  14      16384
# 15  15      32768
# 16  16      65536
# 17  17     131072
# 18  18     262144
# 19  19     524288
# 20  20    1048576
# 21  21    2097152
# 22  22    4194304
# 23  23    8388608
# 24  24   16777216
# 25  25   33554432
# 26  26   67108864
# 27  27  134217728
# 28  28  268435456
# 29  29  536870912

# %%
q = queue.Queue()
def callback(indata, frames, time, status):
    """This is called (from a separate thread) for each audio block."""
    if status:
        print(status, file=sys.stderr)
    # Fancy indexing with mapping creates a (necessary!) copy:
    q.put(indata.copy())


with sdd.InputStream(samplerate=44100, channels=1, callback=callback):
    data = q.get()
    while len(data) < 1e5:
        data = np.append(data,q.get())
    plt.plot(data)
    plt.show()
    
sdd.play(data)

# %%
# Out:
# 0.031280518
# 0.031280517578125

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-87-9ec5b516b17b> in <module>()
# ----> 1 plt.hist(bdat/32760)
#       2 plt.show()
#
# TypeError: unsupported operand type(s) for /: 'tuple' and 'int'

# %%
# Out:
# None
# 0
# 32
# 0.0
# 0.034829931972789115
# ---------------------------------------------------------------------------
# PortAudioError                            Traceback (most recent call last)
# <ipython-input-13-991a3db88723> in <module>()
#       4 print(ris.cpu_load)
#       5 print(ris.latency)
# ----> 6 print(ris.read(50))
#       7 print(ris.stop())
#
# ~/anaconda3/lib/python3.6/site-packages/sounddevice.py in read(self, frames)
#    1105             overflowed = True
#    1106         else:
# -> 1107             _check(err)
#    1108             overflowed = False
#    1109         return _ffi.buffer(data), overflowed
#
# ~/anaconda3/lib/python3.6/site-packages/sounddevice.py in _check(err, msg)
#    2561         raise PortAudioError(errormsg, err, hosterror_info)
#    2562
# -> 2563     raise PortAudioError(errormsg, err)
#    2564
#    2565
#
# PortAudioError: Stream is stopped [PaErrorCode -9983]

# %%
# Out:
# input underflow
# input underflow
# input underflow
# input underflow
